# %%
#Sihao Ren // sren03 // 947105531
using Flux
using Statistics
using Flux: onehotbatch, onecold, crossentropy, throttle
using Base.Iterators: repeated
using Flux: @epochs
using MLJBase
using Printf
using BSON: @save # for save weights
using Plots

# %%
# get data and labels
images = Flux.Data.FashionMNIST.images()
labels = Flux.Data.FashionMNIST.labels();
# the better way is to use MLDatasets, but it doesn't work on jupyter notebook.
# Out:
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data C:\Users\xkzmx\.julia\packages\Flux\qAdFM\src\data\Data.jl:16
# ┌ Warning: Flux's datasets are deprecated, please use the package MLDatasets.jl
# └ @ Flux.Data C:\Users\xkzmx\.julia\packages\Flux\qAdFM\src\data\Data.jl:16

# %%
# this is just to initialize, the 2 data is not used in the model
selectedImages = images[1:2];
selectedLabels = labels[1:2];

# %%
# filter the data so it contains only 0 and 1
for i in 1:60000
    if labels[i] == 0 || labels[i] == 1
        append!(selectedLabels, labels[i])
        push!(selectedImages, images[i])
    end
end

# %%
#size(selectedImages)

# %%
#size(selectedLabels)

# %%
# selectedTrainImage = selectedImages[3:8400]
# selectedTrainLabel = selectedLabels[3:8400]
# selectedTestImage = selectedImages[8401:12000]
# selectedTestLabel = selectedLabels[8401:12000];

# %%
# get part of the selected data.
selectedTrainImage = selectedImages[3:1000]
selectedTrainLabel = selectedLabels[3:1000]
selectedTestImage = selectedImages[1001:1400]
selectedTestLabel = selectedLabels[1001:1400];

# %%
#reshape the data so it can be used in the model
x_train = hcat(float.(reshape.(selectedTrainImage, :))...) 
y_train = onehotbatch(selectedTrainLabel, 0:1)
x_test = hcat(float.(reshape.(selectedTestImage, :))...)
y_test = onehotbatch(selectedTestLabel, 0:1);

# %%
# size(x_train)

# %%
# julia> layer(input)

# %%
#define the model
#784->2*784->2
#output is the probability of being 0 or 1

model = Chain(Dense(28^2, 2*28^2, sigmoid), Dense(2*28^2, 2), 
    softmax)
@save "mymodel10.bson" model #@save "mymodel10.bson" model

# %%
#define the other functions that will be used in the model
loss(x, y) = crossentropy(model(x), y) 
#2
optim = ADAM(); 
dataset = repeated((x_train,y_train),1);
#in the first try, I tried to repeat the data to train, 
#but in the final version I change to loop the train process.
myaccuracy(x, y) = mean(onecold(model(x)) .== onecold(y))
#modified the zoo example from julia
# Out:
# myaccuracy (generic function with 1 method)

# %%
#@epochs 200 Flux.train!(loss, params(model), dataset, optim, cb = throttle(evalcb, 10))

# %%
save_resultTest = []
save_resultTrain = []
epochs = 50 # the number of epochs
# Out:
# 200

# %%
for i = 1:epochs
    Flux.train!(loss, Flux.params(model), dataset, optim)
    @printf("Loss in epoch: %d in test is %f\n", i, loss(x_test, y_test))
    #save the accuracy of the test data
    push!(save_resultTest, myaccuracy(x_test, y_test))
    push!(save_resultTrain, myaccuracy(x_train, y_train))
    #plot(log(i), loss(x_test, y_test))
end
# Out:
# Loss in epoch: 1 in test is 1.039540
# Loss in epoch: 2 in test is 0.334050
# Loss in epoch: 3 in test is 0.494887
# Loss in epoch: 4 in test is 0.485091
# Loss in epoch: 5 in test is 0.299496
# Loss in epoch: 6 in test is 0.205529
# Loss in epoch: 7 in test is 0.195201
# Loss in epoch: 8 in test is 0.211631
# Loss in epoch: 9 in test is 0.222703
# Loss in epoch: 10 in test is 0.216998
# Loss in epoch: 11 in test is 0.196425
# Loss in epoch: 12 in test is 0.168560
# Loss in epoch: 13 in test is 0.141234
# Loss in epoch: 14 in test is 0.120910
# Loss in epoch: 15 in test is 0.112567
# Loss in epoch: 16 in test is 0.116318
# Loss in epoch: 17 in test is 0.125524
# Loss in epoch: 18 in test is 0.132436
# Loss in epoch: 19 in test is 0.131797
# Loss in epoch: 20 in test is 0.122738
# Loss in epoch: 21 in test is 0.108428
# Loss in epoch: 22 in test is 0.093593
# Loss in epoch: 23 in test is 0.082022
# Loss in epoch: 24 in test is 0.075279
# Loss in epoch: 25 in test is 0.072773
# Loss in epoch: 26 in test is 0.072664
# Loss in epoch: 27 in test is 0.072953
# Loss in epoch: 28 in test is 0.072277
# Loss in epoch: 29 in test is 0.070275
# Loss in epoch: 30 in test is 0.067499
# Loss in epoch: 31 in test is 0.064957
# Loss in epoch: 32 in test is 0.063524
# Loss in epoch: 33 in test is 0.063508
# Loss in epoch: 34 in test is 0.064577
# Loss in epoch: 35 in test is 0.065993
# Loss in epoch: 36 in test is 0.066958
# Loss in epoch: 37 in test is 0.066921
# Loss in epoch: 38 in test is 0.065732
# Loss in epoch: 39 in test is 0.063639
# Loss in epoch: 40 in test is 0.061145
# Loss in epoch: 41 in test is 0.058803
# Loss in epoch: 42 in test is 0.057027
# Loss in epoch: 43 in test is 0.055973
# Loss in epoch: 44 in test is 0.055533
# Loss in epoch: 45 in test is 0.055432
# Loss in epoch: 46 in test is 0.055381
# Loss in epoch: 47 in test is 0.055204
# Loss in epoch: 48 in test is 0.054882
# Loss in epoch: 49 in test is 0.054518
# Loss in epoch: 50 in test is 0.054257
# Loss in epoch: 51 in test is 0.054194
# Loss in epoch: 52 in test is 0.054327
# Loss in epoch: 53 in test is 0.054561
# Loss in epoch: 54 in test is 0.054744
# Loss in epoch: 55 in test is 0.054740
# Loss in epoch: 56 in test is 0.054475
# Loss in epoch: 57 in test is 0.053962
# Loss in epoch: 58 in test is 0.053280
# Loss in epoch: 59 in test is 0.052541
# Loss in epoch: 60 in test is 0.051842
# Loss in epoch: 61 in test is 0.051241
# Loss in epoch: 62 in test is 0.050749
# Loss in epoch: 63 in test is 0.050346
# Loss in epoch: 64 in test is 0.050003
# Loss in epoch: 65 in test is 0.049704
# Loss in epoch: 66 in test is 0.049452
# Loss in epoch: 67 in test is 0.049263
# Loss in epoch: 68 in test is 0.049153
# Loss in epoch: 69 in test is 0.049123
# Loss in epoch: 70 in test is 0.049150
# Loss in epoch: 71 in test is 0.049196
# Loss in epoch: 72 in test is 0.049215
# Loss in epoch: 73 in test is 0.049168
# Loss in epoch: 74 in test is 0.049036
# Loss in epoch: 75 in test is 0.048821
# Loss in epoch: 76 in test is 0.048544
# Loss in epoch: 77 in test is 0.048236
# Loss in epoch: 78 in test is 0.047928
# Loss in epoch: 79 in test is 0.047644
# Loss in epoch: 80 in test is 0.047400
# Loss in epoch: 81 in test is 0.047202
# Loss in epoch: 82 in test is 0.047052
# Loss in epoch: 83 in test is 0.046947
# Loss in epoch: 84 in test is 0.046885
# Loss in epoch: 85 in test is 0.046859
# Loss in epoch: 86 in test is 0.046862
# Loss in epoch: 87 in test is 0.046882
# Loss in epoch: 88 in test is 0.046903
# Loss in epoch: 89 in test is 0.046911
# Loss in epoch: 90 in test is 0.046892
# Loss in epoch: 91 in test is 0.046837
# Loss in epoch: 92 in test is 0.046745
# Loss in epoch: 93 in test is 0.046622
# Loss in epoch: 94 in test is 0.046476
# Loss in epoch: 95 in test is 0.046321
# Loss in epoch: 96 in test is 0.046167
# Loss in epoch: 97 in test is 0.046025
# Loss in epoch: 98 in test is 0.045901
# Loss in epoch: 99 in test is 0.045800
# Loss in epoch: 100 in test is 0.045722
# Loss in epoch: 101 in test is 0.045666
# Loss in epoch: 102 in test is 0.045630
# Loss in epoch: 103 in test is 0.045608
# Loss in epoch: 104 in test is 0.045594
# Loss in epoch: 105 in test is 0.045582
# Loss in epoch: 106 in test is 0.045564
# Loss in epoch: 107 in test is 0.045536
# Loss in epoch: 108 in test is 0.045493
# Loss in epoch: 109 in test is 0.045436
# Loss in epoch: 110 in test is 0.045364
# Loss in epoch: 111 in test is 0.045283
# Loss in epoch: 112 in test is 0.045196
# Loss in epoch: 113 in test is 0.045109
# Loss in epoch: 114 in test is 0.045027
# Loss in epoch: 115 in test is 0.044953
# Loss in epoch: 116 in test is 0.044888
# Loss in epoch: 117 in test is 0.044836
# Loss in epoch: 118 in test is 0.044794
# Loss in epoch: 119 in test is 0.044762
# Loss in epoch: 120 in test is 0.044737
# Loss in epoch: 121 in test is 0.044716
# Loss in epoch: 122 in test is 0.044695
# Loss in epoch: 123 in test is 0.044673
# Loss in epoch: 124 in test is 0.044646
# Loss in epoch: 125 in test is 0.044613
# Loss in epoch: 126 in test is 0.044574
# Loss in epoch: 127 in test is 0.044530
# Loss in epoch: 128 in test is 0.044482
# Loss in epoch: 129 in test is 0.044432
# Loss in epoch: 130 in test is 0.044382
# Loss in epoch: 131 in test is 0.044335
# Loss in epoch: 132 in test is 0.044292
# Loss in epoch: 133 in test is 0.044254
# Loss in epoch: 134 in test is 0.044221
# Loss in epoch: 135 in test is 0.044194
# Loss in epoch: 136 in test is 0.044172
# Loss in epoch: 137 in test is 0.044152
# Loss in epoch: 138 in test is 0.044135
# Loss in epoch: 139 in test is 0.044117
# Loss in epoch: 140 in test is 0.044099
# Loss in epoch: 141 in test is 0.044079
# Loss in epoch: 142 in test is 0.044056
# Loss in epoch: 143 in test is 0.044031
# Loss in epoch: 144 in test is 0.044005
# Loss in epoch: 145 in test is 0.043977
# Loss in epoch: 146 in test is 0.043949
# Loss in epoch: 147 in test is 0.043922
# Loss in epoch: 148 in test is 0.043897
# Loss in epoch: 149 in test is 0.043874
# Loss in epoch: 150 in test is 0.043854
# Loss in epoch: 151 in test is 0.043837
# Loss in epoch: 152 in test is 0.043822
# Loss in epoch: 153 in test is 0.043810
# Loss in epoch: 154 in test is 0.043799
# Loss in epoch: 155 in test is 0.043789
# Loss in epoch: 156 in test is 0.043780
# Loss in epoch: 157 in test is 0.043770
# Loss in epoch: 158 in test is 0.043759
# Loss in epoch: 159 in test is 0.043748
# Loss in epoch: 160 in test is 0.043736
# Loss in epoch: 161 in test is 0.043724
# Loss in epoch: 162 in test is 0.043712
# Loss in epoch: 163 in test is 0.043701
# Loss in epoch: 164 in test is 0.043691
# Loss in epoch: 165 in test is 0.043682
# Loss in epoch: 166 in test is 0.043674
# Loss in epoch: 167 in test is 0.043669
# Loss in epoch: 168 in test is 0.043665
# Loss in epoch: 169 in test is 0.043662
# Loss in epoch: 170 in test is 0.043661
# Loss in epoch: 171 in test is 0.043660
# Loss in epoch: 172 in test is 0.043660
# Loss in epoch: 173 in test is 0.043660
# Loss in epoch: 174 in test is 0.043661
# Loss in epoch: 175 in test is 0.043661
# Loss in epoch: 176 in test is 0.043662
# Loss in epoch: 177 in test is 0.043662
# Loss in epoch: 178 in test is 0.043663
# Loss in epoch: 179 in test is 0.043664
# Loss in epoch: 180 in test is 0.043667
# Loss in epoch: 181 in test is 0.043670
# Loss in epoch: 182 in test is 0.043674
# Loss in epoch: 183 in test is 0.043679
# Loss in epoch: 184 in test is 0.043686
# Loss in epoch: 185 in test is 0.043693
# Loss in epoch: 186 in test is 0.043701
# Loss in epoch: 187 in test is 0.043710
# Loss in epoch: 188 in test is 0.043720
# Loss in epoch: 189 in test is 0.043729
# Loss in epoch: 190 in test is 0.043740
# Loss in epoch: 191 in test is 0.043750
# Loss in epoch: 192 in test is 0.043761
# Loss in epoch: 193 in test is 0.043772
# Loss in epoch: 194 in test is 0.043784
# Loss in epoch: 195 in test is 0.043796
# Loss in epoch: 196 in test is 0.043809
# Loss in epoch: 197 in test is 0.043822
# Loss in epoch: 198 in test is 0.043837
# Loss in epoch: 199 in test is 0.043852
# Loss in epoch: 200 in test is 0.043868

# %%
# plot the accuracy in jupyter notebook
plot(log.(1:epochs), save_resultTest)
plot!(log.(1:epochs), save_resultTrain, title = "Accuracy")

# %%
# change the output from probability into  0 or 1

simplified_x_test_result = []
for i  = 1:400 
    if model(x_test[:,i])[1]>0.5
        push!(simplified_x_test_result, 0)
    else
        push!(simplified_x_test_result, 1)
    end
end
simplified_y_test = []
for i  = 1:400 
    if y_test[:,i][1] == true
        push!(simplified_y_test, 0)
    else
        push!(simplified_y_test, 1)
    end
end

# %%
# ConfusionMatrix for the test data

ConfusionMatrix()(simplified_x_test_result, simplified_y_test )
# Out:
# ┌ Warning: The classes are un-ordered,
# │ using: negative='0' and positive='1'.
# │ To suppress this warning, consider coercing to OrderedFactor.
# └ @ MLJBase C:\Users\xkzmx\.julia\packages\MLJBase\pCiRR\src\measures\confusion_matrix.jl:112
#               ┌───────────────────────────┐
#               │       Ground Truth        │
# ┌─────────────┼─────────────┬─────────────┤
# │  Predicted  │      0      │      1      │
# ├─────────────┼─────────────┼─────────────┤
# │      0      │     193     │      1      │
# ├─────────────┼─────────────┼─────────────┤
# │      1      │      5      │     201     │
# └─────────────┴─────────────┴─────────────┘

# %%
# change the output from probability into  0 or 1

simplified_x_train_result = []
for i  = 1:998 
    if model(x_train[:,i])[1]>0.5
        push!(simplified_x_train_result, 0)
    else
        push!(simplified_x_train_result, 1)
    end
end
simplified_y_train = []
for i  = 1:998 
    if y_train[:,i][1] == true
        push!(simplified_y_train, 0)
    else
        push!(simplified_y_train, 1)
    end
end

# %%
# ConfusionMatrix for the training data
print("ConfusionMatrix for the training data\n")
ConfusionMatrix()(simplified_x_train_result, simplified_y_train )
# Out:
# ┌ Warning: The classes are un-ordered,
# │ using: negative='0' and positive='1'.
# │ To suppress this warning, consider coercing to OrderedFactor.
# └ @ MLJBase C:\Users\xkzmx\.julia\packages\MLJBase\pCiRR\src\measures\confusion_matrix.jl:112
#               ┌───────────────────────────┐
#               │       Ground Truth        │
# ┌─────────────┼─────────────┬─────────────┤
# │  Predicted  │      0      │      1      │
# ├─────────────┼─────────────┼─────────────┤
# │      0      │     449     │      6      │
# ├─────────────┼─────────────┼─────────────┤
# │      1      │      3      │     540     │
# └─────────────┴─────────────┴─────────────┘
