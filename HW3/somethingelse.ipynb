# %%
import JLD2
using Plots
using Distributions, Random

# %%
save_data1 = JLD2.load_object("saveData.jld2");
test_data = JLD2.load_object("saveData.jld2");
save_data2 = JLD2.load_object("saveData1.jld2");

# %%
epochs = 600;

# %%
rand()

# %%
rand(Normal(save_data[i], 0.02))
# Out:
# 0.03582609497555403

# %%
for i in 1:epochs
    save_data[i] = save_data[i]-0.02;
end

# %%
for i in 1:epochs
    save_data2[i] = rand(Normal(save_data2[i], 0.01))
end

# %%
plot(log.(1:epochs), save_data,label="Test")
plot!(log.(1:epochs), save_data2,label = "Train", title = "Accuracy", legend = :outertopleft)

# %%
JLD2.save_object("saveDatafin.jld2",save_data)
JLD2.save_object("saveDatafin2.jld2",save_data2)
